# %%
# Задание "Линейная регрессия". Выполнил Даниэль Момот, СПбПУ Петра Великого

# %%
from sklearn import linear_model, datasets, metrics
from matplotlib.pyplot import figure
import math
import random

# %%
my_number = 26

samples = my_number * 10
features = my_number
informative = math.ceil(my_number * 0.2)
o_noise = random.randint(1, 20)

# Generate dataset
data, target, coef = datasets.make_regression(n_samples = samples, n_features = features,
                                              n_informative = informative, noise = o_noise, coef = True)

# %%
# Draw plots. We can see that features values are normally distributed
for i in range(my_number):
    pyplot.figure(figsize = (5, 5))
    pyplot.scatter(list(map(lambda x:x[i], data)), target, color = 'b')
    pyplot.xlabel('feature ' + str(i+1))
    pyplot.ylabel('target')
# Out:
# <ipython-input-149-253aea5c1941>:3: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   pyplot.figure(figsize = (5, 5))

# %%
# Learn linear regression model
regression_model = linear_model.LinearRegression()
fff = regression_model.fit(data, target)

# %%
# Output linear regression model as equation
strr = "y = "
for id, val in enumerate(regression_model.coef_):
    strr += str(round(val, 2)) + " * x" + str(id) + " + "
strr += str(round(regression_model.intercept_, 2))

print ("Equation for linear model:")
print(strr)
# Out:
# Equation for linear model:
# y = 0.26 * x0 + 0.68 * x1 + -0.49 * x2 + -1.44 * x3 + -0.83 * x4 + 0.24 * x5 + 66.25 * x6 + -0.08 * x7 + 63.47 * x8 + 65.67 * x9 + 0.52 * x10 + -0.12 * x11 + -0.4 * x12 + 0.0 * x13 + 0.21 * x14 + 0.7 * x15 + 40.64 * x16 + -1.04 * x17 + 84.75 * x18 + 0.2 * x19 + 0.43 * x20 + -0.01 * x21 + 1.38 * x22 + 0.71 * x23 + 91.07 * x24 + 1.24 * x25 + 0.7

# %%
# Evaluate RMSE
predictions = regression_model.predict(data)
rmse = metrics.mean_squared_error(y_true=target, y_pred=predictions, squared=False)
print ('RMSE = ', rmse)
# Out:
# RMSE =  11.270014853555805
